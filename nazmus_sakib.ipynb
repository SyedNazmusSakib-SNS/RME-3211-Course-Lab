# %% [markdown]
# <div style="border-radius:30px; border:#DEB887 solid; padding: 0px; background-color: #FFFAF0; font-size:100%; text-align:left; color: #000000;">
# <h1 align="center"><font color='#DAA520'>Lab Assignment</font></h1>
# <h2 align="center"><font color='#8B4513'>Bias Variance Tradeoff</font></h2>
#
# <br>
#
# <table style="width:95%; border:none; background-color: transparent; align: center">
#   <tr>
#     <td style="width:40%; vertical-align:top; padding-right:10px; color: #000000;">
#       <p style="color: #000000;"><strong>Student Information:</strong></p>
#       <p style="color: #000000;"><strong>Name:</strong> Syed Nazmus Sakib</p>
#       <p style="color: #000000;"><strong>Roll:</strong> AE-172-009</p>
#     </td>
#     <td style="width:40%; vertical-align:top; color: #000000; text-align:center">
#       <p style="color: #000000;"><strong>Course Details:</strong></p>
#       <p style="color: #000000;"><strong>Course:</strong> Intelligent Systems and Robotics</p>
#       <p style="color: #000000;"><strong>Course Code:</strong> RME-3211</p>
#     </td>
#   </tr>
# </table>
#
# <div style="text-align:center; margin-top:20px; color: #000000;">
#   <p style="margin:0; color: #000000;"><strong>Submitted to:</strong></p>
#   <p style="margin:0; color: #000000;"><strong>Dr. Sejuti Rahman</strong></p>
#   <p style="margin:0; color: #000000;"><strong>Associate Professor and Chairperson</strong></p>
#   <p style="margin:0; color: #000000;"><strong>Department of Robotics and Mechatronics Engineering</strong></p>
#   <p style="margin:0; color: #000000;"><strong>University of Dhaka</strong></p>
# </div>
# </div>

# %% [markdown]
# <div style="border-radius:50px; border:#DEB887 solid; padding: 0px; background-color: #FFFAF0; font-size:100%; text-align:left; color: #000000;">
# <h2 align="center"><font color='#8B4513'>Assignment Outline</font></h2>
#
# <div style="display: flex; justify-content: center;">
#   <div style="width: 80%; max-width: 800px;">
#     <table style="width:100%; border-collapse: separate; border-spacing: 0 10px;">
#       <tr>
#         <td style="padding: 10px 15px; background-color: #DAA520; color: white; border-radius: 5px; font-weight: bold;">1</td>
#         <td style="padding: 10px 15px; background-color: #F5F5DC; border-radius: 5px; font-weight: bold; color: #8B4513;">
#           <a href="#imports" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">Imports</a>
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px 15px; background-color: #DAA520; color: white; border-radius: 5px; font-weight: bold;">2</td>
#         <td style="padding: 10px 15px; background-color: #F5F5DC; border-radius: 5px; font-weight: bold; color: #8B4513;">
#           <a href="#data_loading" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">Data Loading</a>
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px 15px; background-color: #DAA520; color: white; border-radius: 5px; font-weight: bold;">3</td>
#         <td style="padding: 10px 15px; background-color: #F5F5DC; border-radius: 5px; font-weight: bold; color: #8B4513;">
#           <a href="#train_test_split" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">Train-Test Split</a>
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px 15px; background-color: #DAA520; color: white; border-radius: 5px; font-weight: bold;">4</td>
#         <td style="padding: 10px 15px; background-color: #F5F5DC; border-radius: 5px; font-weight: bold; color: #8B4513;">
#           <a href="#modeling" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">Modeling</a>
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px 15px;"></td>
#         <td style="padding: 0 15px;">
#           <table style="width: 100%; border-collapse: separate; border-spacing: 0 8px; margin-left: 20px;">
#             <tr>
#               <td style="padding: 8px 15px; background-color: #EEE8AA; border-radius: 5px; color: #8B4513;">
#                 <a href="#poly_degree_1" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">4.1 Polynomial Degree 1</a>
#               </td>
#             </tr>
#             <tr>
#               <td style="padding: 8px 15px; background-color: #EEE8AA; border-radius: 5px; color: #8B4513;">
#                 <a href="#poly_degree_2" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">4.2 Polynomial Degree 2</a>
#               </td>
#             </tr>
#             <tr>
#               <td style="padding: 8px 15px; background-color: #EEE8AA; border-radius: 5px; color: #8B4513;">
#                 <a href="#poly_degree_3" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">4.3 Polynomial Degree 3</a>
#               </td>
#             </tr>
#             <tr>
#               <td style="padding: 8px 15px; background-color: #EEE8AA; border-radius: 5px; color: #8B4513;">
#                 <a href="#poly_degree_4" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">4.4 Polynomial Degree 4</a>
#               </td>
#             </tr>
#             <tr>
#               <td style="padding: 8px 15px; background-color: #EEE8AA; border-radius: 5px; color: #8B4513;">
#                 <a href="#poly_degree_5" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">4.5 Polynomial Degree 5</a>
#               </td>
#             </tr>
#             <tr>
#               <td style="padding: 8px 15px; background-color: #EEE8AA; border-radius: 5px; color: #8B4513;">
#                 <a href="#poly_degree_6" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">4.6 Polynomial Degree 6</a>
#               </td>
#             </tr>
#           </table>
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px 15px; background-color: #DAA520; color: white; border-radius: 5px; font-weight: bold;">6</td>
#         <td style="padding: 10px 15px; background-color: #F5F5DC; border-radius: 5px; font-weight: bold; color: #8B4513;">
#           <a href="#poly_selected_features" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">Polynomial Terms for Selected Features</a>
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px 15px; background-color: #DAA520; color: white; border-radius: 5px; font-weight: bold;">7</td>
#         <td style="padding: 10px 15px; background-color: #F5F5DC; border-radius: 5px; font-weight: bold; color: #8B4513;">
#           <a href="#bias_variance_analysis" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">Bias-Variance Analysis</a>
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px 15px;"></td>
#         <td style="padding: 0 15px;">
#           <table style="width: 100%; border-collapse: separate; border-spacing: 0 8px; margin-left: 20px;">
#             <tr>
#               <td style="padding: 8px 15px; background-color: #EEE8AA; border-radius: 5px; color: #8B4513;">
#                 <a href="#rmse" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">7.1 RMSE</a>
#               </td>
#             </tr>
#             <tr>
#               <td style="padding: 8px 15px; background-color: #EEE8AA; border-radius: 5px; color: #8B4513;">
#                 <a href="#r_squared" style="text-decoration: none; color: #8B4513; display: block; width: 100%;">7.2 R²</a>
#               </td>
#             </tr>
#           </table>
#         </td>
#       </tr>
#     </table>
#   </div>
# </div>
# </div>

# %% [markdown]
# <a id="imports"></a>
# <div style="border-radius:4px; border-left:5px solid #DAA520; padding: 0px; background-color: #FFFAF0; font-size:100%; margin-bottom: 20px;">
#   <h2 style="color: #8B4513; margin-top: 0;">1. Imports</h2>
#   <p style="color: #000000;">In this section, we import all necessary libraries for our bias-variance tradeoff analysis.</p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# <a id="data_loading"></a>
# <div style="border-radius:10px; border-left:5px solid #DAA520; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-bottom: 20px;">
#   <h2 style="color: #8B4513; margin-top: 0;">2. Data Loading</h2>
#   <p style="color: #000000;">Here I load the dataset that will be used for our polynomial regression models.</p>
# </div>

# %%
df = pd.read_csv('boston_housing.csv')

# %%
df.head()
# Out:
#    id     CRIM    ZN  INDUS  CHAS  ...  TAX  PTRATIO       B  LSTAT  class
# 0   1  0.00632  18.0   2.31     0  ...  296     15.3  396.90   4.98   24.0
# 1   2  0.02731   0.0   7.07     0  ...  242     17.8  396.90   9.14   21.6
# 2   3  0.02729   0.0   7.07     0  ...  242     17.8  392.83   4.03   34.7
# 3   4  0.03237   0.0   2.18     0  ...  222     18.7  394.63   2.94   33.4
# 4   5  0.06905   0.0   2.18     0  ...  222     18.7  396.90   5.33   36.2
#
# [5 rows x 15 columns]

# %%
df.columns.to_list()
# Out:
# ['id',
#  'CRIM',
#  'ZN',
#  'INDUS',
#  'CHAS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT',
#  'class']

# %% [markdown]
# - Column names are too cryptic
# - converting them into meaningful column names

# %%
# Define a dictionary mapping old column names to new ones
new_column_names = {
    'id': 'Property_ID',
    'CRIM': 'Crime_Rate',
    'ZN': 'Residential_Zoning',
    'INDUS': 'Industrial_Pct',
    'CHAS': 'Charles_River_Access',
    'NOX': 'Nitrogen_Oxides',
    'RM': 'Avg_Rooms',
    'AGE': 'Pre_War_Built_Pct',
    'DIS': 'Employment_Center_Dist',
    'RAD': 'Highway_Access',
    'TAX': 'Property_TaxRate',
    'PTRATIO': 'Pupil_Teacher_Ratio',
    'B': 'Black_Residents_Pct',
    'LSTAT': 'Lower_Status_Pct',
    'class': 'Price'
}

df.rename(columns=new_column_names, inplace=True)

print(df.head())
# Out:
#    Property_ID  Crime_Rate  ...  Lower_Status_Pct  Price
# 0            1     0.00632  ...              4.98   24.0
# 1            2     0.02731  ...              9.14   21.6
# 2            3     0.02729  ...              4.03   34.7
# 3            4     0.03237  ...              2.94   33.4
# 4            5     0.06905  ...              5.33   36.2
#
# [5 rows x 15 columns]

# %% [markdown]
# <a id="train_test_split"></a>
# <div style="border-radius:10px; border-left:5px solid #DAA520; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-bottom: 20px;">
#   <h2 style="color: #8B4513; margin-top: 0;">3. Train-Test Split</h2>
#   <p style="color: #000000;">I split our dataset into training and testing sets to evaluate our models properly.</p>
# </div>

# %%
X = df.drop(['Price', 'Property_ID'], axis=1)
y = df['Price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# <a id="modeling"></a>
# <div style="border-radius:10px; border-left:5px solid #DAA520; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-bottom: 20px;">
#   <h2 style="color: #8B4513; margin-top: 0;">4. Modeling</h2>
#   <p style="color: #000000;">In this section, I created polynomial regression models of different degrees to observe the bias-variance tradeoff.</p>
# </div>

# %% [markdown]
# <a id="poly_degree_1"></a>
# <div style="border-radius:10px; border-left:5px solid #EEE8AA; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-left: 30px; margin-bottom: 20px;">
#   <h3 style="color: #8B4513; margin-top: 0;">4.1 Polynomial Degree 1</h3>
#   <p style="color: #000000;">Linear regression model using polynomial features of degree 1.</p>
# </div>

# %%
# Degree 1 polynomial features (i.e., linear regression)
poly_1 = PolynomialFeatures(degree=1, include_bias=False)
X_train_poly_1 = poly_1.fit_transform(X_train)
X_test_poly_1 = poly_1.transform(X_test)

# %%
# Fit linear regression
linreg_1 = LinearRegression()
linreg_1.fit(X_train_poly_1, y_train)
# Out:
# LinearRegression()

# %%
# Intercept and coefficients
print("Intercept:", linreg_1.intercept_)
print("\nCoefficients:")
for name, coef in zip(X.columns, linreg_1.coef_):
    print(f"{name:25s}: {coef:.4f}")
# Out:
# Intercept: 31.63108403569288
#
# Coefficients:
# Crime_Rate               : -0.1335
# Residential_Zoning       : 0.0358
# Industrial_Pct           : 0.0495
# Charles_River_Access     : 3.1198
# Nitrogen_Oxides          : -15.4171
# Avg_Rooms                : 4.0572
# Pre_War_Built_Pct        : -0.0108
# Employment_Center_Dist   : -1.3860
# Highway_Access           : 0.2427
# Property_TaxRate         : -0.0087
# Pupil_Teacher_Ratio      : -0.9107
# Black_Residents_Pct      : 0.0118
# Lower_Status_Pct         : -0.5471

# %%
# Feature importance (absolute value of coefficients)
feature_importance = pd.Series(np.abs(linreg_1.coef_), index=X.columns)
top10 = feature_importance.sort_values(ascending=False).head(10)
print("\nTop 10 Feature Importances:")
print(top10)
# Out:
# Top 10 Feature Importances:
# Nitrogen_Oxides           15.417061
# Avg_Rooms                  4.057199
# Charles_River_Access       3.119835
# Employment_Center_Dist     1.385998
# Pupil_Teacher_Ratio        0.910685
# Lower_Status_Pct           0.547113
# Highway_Access             0.242727
# Crime_Rate                 0.133470
# Industrial_Pct             0.049523
# Residential_Zoning         0.035809
# dtype: float64

# %%
# Predictions
y_train_pred_1 = linreg_1.predict(X_train_poly_1)
y_test_pred_1 = linreg_1.predict(X_test_poly_1)

# Metrics
train_rmse_1 = root_mean_squared_error(y_train, y_train_pred_1)
test_rmse_1 = root_mean_squared_error(y_test, y_test_pred_1)
train_r2_1 = r2_score(y_train, y_train_pred_1)
test_r2_1 = r2_score(y_test, y_test_pred_1)

print(f"\nTrain RMSE for Degree 1: {train_rmse_1:.4f}")
print(f"Test RMSE for Degree 1:  {test_rmse_1:.4f}")
print(f"Train R2 for Degree 1:   {train_r2_1:.4f}")
print(f"Test R2 for Degree 1:    {test_r2_1:.4f}")
# Out:
# Train RMSE for Degree 1: 4.7482
# Test RMSE for Degree 1:  4.6387
# Train R2 for Degree 1:   0.7435
# Test R2 for Degree 1:    0.7112

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred_1, alpha=0.7, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price (Degree 1)')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="poly_degree_2"></a>
# <div style="border-radius:10px; border-left:5px solid #EEE8AA; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-left: 30px; margin-bottom: 20px;">
#   <h3 style="color: #8B4513; margin-top: 0;">4.2 Polynomial Degree 2</h3>
#   <p style="color: #000000;">Regression model using polynomial features of degree 2.</p>
# </div>

# %%
# Degree 2 polynomial features 
poly_2 = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly_2 = poly_2.fit_transform(X_train)
X_test_poly_2 = poly_2.transform(X_test)

# %%
# Fit linear regression
linreg_2 = LinearRegression()
linreg_2.fit(X_train_poly_2, y_train)
# Out:
# LinearRegression()

# %%
# Intercept and coefficients
print("Intercept:", linreg_2.intercept_)

print("Number of Original features:", X_train.shape[1])

print("Number of Total features:", X_train_poly_2.shape[1])

print("Number of Squared features:", X_train_poly_2.shape[1] - X_train.shape[1])

print("Number of Interaction features:", X_train_poly_2.shape[1] - X_train.shape[1] - X_train.shape[1])
print("\nCoefficients:")

# Show all coefficients with their corresponding feature names for degree 2 polynomial features
feature_names_2 = poly_2.get_feature_names_out(X.columns)
for name, coef in zip(feature_names_2, linreg_2.coef_):
    print(f"{name:40s}: {coef:.4f}")
# Out:
# Intercept: -239.95478592429964
# Number of Original features: 13
# Number of Total features: 104
# Number of Squared features: 91
# Number of Interaction features: 78
#
# Coefficients:
# Crime_Rate                              : -8.6564
# Residential_Zoning                      : 0.3280
# Industrial_Pct                          : -5.2200
# Charles_River_Access                    : 32.6596
# Nitrogen_Oxides                         : 314.6767
# Avg_Rooms                               : 14.2019
# Pre_War_Built_Pct                       : 0.7541
# Employment_Center_Dist                  : 3.4747
# Highway_Access                          : 0.4010
# Property_TaxRate                        : 0.1916
# Pupil_Teacher_Ratio                     : 4.8684
# Black_Residents_Pct                     : 0.2167
# Lower_Status_Pct                        : -0.7990
# Crime_Rate^2                            : 0.0021
# Crime_Rate Residential_Zoning           : 0.0443
# ...

# %%
# Feature importance (absolute value of coefficients)
feature_importance_2 = pd.Series(np.abs(linreg_2.coef_), index=feature_names_2)
top10_2 = feature_importance_2.sort_values(ascending=False).head(10)
print("\nTop 10 Feature Importances for degee 2:")
print(top10_2)
# Out:
# Top 10 Feature Importances for degee 2:
# Nitrogen_Oxides                           314.676694
# Nitrogen_Oxides^2                         115.505546
# Charles_River_Access Nitrogen_Oxides       36.350051
# Charles_River_Access^2                     32.659556
# Charles_River_Access                       32.659555
# Avg_Rooms                                  14.201919
# Nitrogen_Oxides Pupil_Teacher_Ratio        13.982326
# Nitrogen_Oxides Employment_Center_Dist     11.469342
# Crime_Rate                                  8.656416
# Nitrogen_Oxides Avg_Rooms                   7.604622
# dtype: float64

# %%
# Predictions
y_train_pred_2 = linreg_2.predict(X_train_poly_2)
y_test_pred_2 = linreg_2.predict(X_test_poly_2)

# Metrics
train_rmse_2 = root_mean_squared_error(y_train, y_train_pred_2)
test_rmse_2 = root_mean_squared_error(y_test, y_test_pred_2)
train_r2_2 = r2_score(y_train, y_train_pred_2)
test_r2_2 = r2_score(y_test, y_test_pred_2)

print(f"\nTrain RMSE for Degree 2: {train_rmse_2:.4f}")
print(f"Test RMSE for Degree 2:  {test_rmse_2:.4f}")
print(f"Train R2 for Degree 2:   {train_r2_2:.4f}")
print(f"Test R2 for Degree 2:    {test_r2_2:.4f}")
# Out:
# Train RMSE for Degree 2: 2.1588
# Test RMSE for Degree 2:  5.0257
# Train R2 for Degree 2:   0.9470
# Test R2 for Degree 2:    0.6610

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred_2, alpha=0.7, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price (Degree 2)')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="poly_degree_3"></a>
# <div style="border-radius:10px; border-left:5px solid #EEE8AA; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-left: 30px; margin-bottom: 20px;">
#   <h3 style="color: #8B4513; margin-top: 0;">4.3 Polynomial Degree 3</h3>
#   <p style="color: #000000;">Regression model using polynomial features of degree 3.</p>
# </div>

# %%
# Degree 3 polynomial features 
poly_3 = PolynomialFeatures(degree=3, include_bias=False)
X_train_poly_3 = poly_3.fit_transform(X_train)
X_test_poly_3 = poly_3.transform(X_test)

# %%
# Fit linear regression
linreg_3 = LinearRegression()
linreg_3.fit(X_train_poly_3, y_train)
# Out:
# LinearRegression()

# %%
# Intercept and coefficients
print("Intercept:", linreg_3.intercept_)

print("Number of Original features:", X_train.shape[1])

print("Number of Total features:", X_train_poly_3.shape[1])

print("Number of Interaction features:", X_train_poly_3.shape[1] - X_train.shape[1] - X_train.shape[1])
print("\nCoefficients:")

# # Show all coefficients with their corresponding feature names for degree 2 polynomial features
# feature_names_3 = poly_3.get_feature_names_out(X.columns)
# for name, coef in zip(feature_names_3, linreg_3.coef_):
#     print(f"{name:60s}: {coef:.4f}")

print("The Above code is commented out to avoid printing too many lines. You can uncomment it to see the coefficients.")
# Out:
# Intercept: -648.4222236254893
# Number of Original features: 13
# Number of Total features: 559
# Number of Interaction features: 533
#
# Coefficients:
# The Above code is commented out to avoid printing too many lines. You can uncomment it to see the coefficients.

# %%
# Feature importance (absolute value of coefficients)
feature_importance_3 = pd.Series(np.abs(linreg_3.coef_), index=feature_names_3)
top10_3 = feature_importance_3.sort_values(ascending=False).head(10)
print("\nTop 10 Feature Importances for degee 2:")
print(top10_3)
# Out:
# Top 10 Feature Importances for degee 2:
# Nitrogen_Oxides Pre_War_Built_Pct Employment_Center_Dist    3.870655
# Avg_Rooms^2 Pupil_Teacher_Ratio                             2.754096
# Crime_Rate Nitrogen_Oxides Lower_Status_Pct                 2.160079
# Crime_Rate Residential_Zoning Employment_Center_Dist        1.847679
# Highway_Access Pupil_Teacher_Ratio^2                        1.763226
# Avg_Rooms Employment_Center_Dist^2                          1.755202
# Nitrogen_Oxides^2 Black_Residents_Pct                       1.730577
# Highway_Access^3                                            1.467032
# Employment_Center_Dist^2 Pupil_Teacher_Ratio                1.426371
# Crime_Rate Nitrogen_Oxides Pre_War_Built_Pct                1.387510
# dtype: float64

# %%
# Predictions
y_train_pred_3 = linreg_3.predict(X_train_poly_3)
y_test_pred_3 = linreg_3.predict(X_test_poly_3)

# Metrics
train_rmse_3 = root_mean_squared_error(y_train, y_train_pred_3)
test_rmse_3 = root_mean_squared_error(y_test, y_test_pred_3)
train_r2_3 = r2_score(y_train, y_train_pred_3)
test_r2_3 = r2_score(y_test, y_test_pred_3)

print(f"\nTrain RMSE for Degree 3: {train_rmse_3:.4f}")
print(f"Test RMSE for Degree 3:  {test_rmse_3:.4f}")
print(f"Train R2 for Degree 3:   {train_r2_3:.4f}")
print(f"Test R2 for Degree 3:    {test_r2_3:.4f}")
# Out:
# Train RMSE for Degree 3: 0.0000
# Test RMSE for Degree 3:  167.7589
# Train R2 for Degree 3:   1.0000
# Test R2 for Degree 3:    -376.6928

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred_3, alpha=0.7, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price (Degree 3)')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="poly_degree_4"></a>
# <div style="border-radius:10px; border-left:5px solid #EEE8AA; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-left: 30px; margin-bottom: 20px;">
#   <h3 style="color: #8B4513; margin-top: 0;">4.4 Polynomial Degree 4</h3>
#   <p style="color: #000000;">Regression model using polynomial features of degree 4.</p>
# </div>

# %%
# Degree 3 polynomial features 
poly_4 = PolynomialFeatures(degree=4, include_bias=False)
X_train_poly_4 = poly_4.fit_transform(X_train)
X_test_poly_4 = poly_4.transform(X_test)

# %%
# Fit linear regression
linreg_4 = LinearRegression()
linreg_4.fit(X_train_poly_4, y_train)
# Out:
# LinearRegression()

# %%
# Intercept and coefficients
print("Intercept:", linreg_4.intercept_)

print("Number of Original features:", X_train.shape[1])

print("Number of Total features:", X_train_poly_4.shape[1])

print("Number of Interaction features:", X_train_poly_4.shape[1] - X_train.shape[1] - X_train.shape[1])
print("\nCoefficients:")

# # Show all coefficients with their corresponding feature names for degree 2 polynomial features
feature_names_4 = poly_4.get_feature_names_out(X.columns)
# for name, coef in zip(feature_names_4, linreg_4.coef_):
#     print(f"{name:60s}: {coef:.4f}")

print("The Above code is commented out to avoid printing too many lines. You can uncomment it to see the coefficients.")
# Out:
# Intercept: -123.92383229159189
# Number of Original features: 13
# Number of Total features: 2379
# Number of Interaction features: 2353
#
# Coefficients:
# The Above code is commented out to avoid printing too many lines. You can uncomment it to see the coefficients.

# %%
# Feature importance (absolute value of coefficients)
feature_importance_4 = pd.Series(np.abs(linreg_4.coef_), index=feature_names_4)
top10_4 = feature_importance_4.sort_values(ascending=False).head(10)
print("\nTop 10 Feature Importances for degee 2:")
print(top10_4)
# Out:
# Top 10 Feature Importances for degee 2:
# Crime_Rate Pre_War_Built_Pct Employment_Center_Dist Property_TaxRate         0.000208
# Residential_Zoning Pre_War_Built_Pct Property_TaxRate Pupil_Teacher_Ratio    0.000192
# Avg_Rooms Pre_War_Built_Pct Pupil_Teacher_Ratio Black_Residents_Pct          0.000179
# Crime_Rate Industrial_Pct Pre_War_Built_Pct Property_TaxRate                 0.000178
# Industrial_Pct Avg_Rooms Property_TaxRate Black_Residents_Pct                0.000178
# Avg_Rooms Highway_Access Property_TaxRate Black_Residents_Pct                0.000171
# Crime_Rate Employment_Center_Dist Black_Residents_Pct^2                      0.000156
# Crime_Rate Employment_Center_Dist Property_TaxRate Black_Residents_Pct       0.000156
# Crime_Rate Avg_Rooms Pre_War_Built_Pct Black_Residents_Pct                   0.000151
# Industrial_Pct^2 Employment_Center_Dist Black_Residents_Pct                  0.000150
# dtype: float64

# %%
# Predictions
y_train_pred_4 = linreg_4.predict(X_train_poly_4)
y_test_pred_4 = linreg_4.predict(X_test_poly_4)

# Metrics
train_rmse_4 = root_mean_squared_error(y_train, y_train_pred_4)
test_rmse_4 = root_mean_squared_error(y_test, y_test_pred_4)
train_r2_4 = r2_score(y_train, y_train_pred_4)
test_r2_4 = r2_score(y_test, y_test_pred_4)

print(f"\nTrain RMSE for Degree 4: {train_rmse_4:.4f}")
print(f"Test RMSE for Degree 4:  {test_rmse_4:.4f}")
print(f"Train R2 for Degree 4:   {train_r2_4:.4f}")
print(f"Test R2 for Degree 4:    {test_r2_4:.4f}")
# Out:
# Train RMSE for Degree 4: 0.0000
# Test RMSE for Degree 4:  283.8173
# Train R2 for Degree 4:   1.0000
# Test R2 for Degree 4:    -1080.0481

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred_4, alpha=0.7, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price (Degree 4)')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="poly_degree_5"></a>
# <div style="border-radius:10px; border-left:5px solid #EEE8AA; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-left: 30px; margin-bottom: 20px;">
#   <h3 style="color: #8B4513; margin-top: 0;">4.5 Polynomial Degree 5</h3>
#   <p style="color: #000000;">Regression model using polynomial features of degree 5.</p>
# </div>

# %%
# Degree 5 polynomial features 
poly_5 = PolynomialFeatures(degree=5, include_bias=False)
X_train_poly_5 = poly_5.fit_transform(X_train)
X_test_poly_5 = poly_5.transform(X_test)

# %%
# Fit linear regression
linreg_5 = LinearRegression()
linreg_5.fit(X_train_poly_5, y_train)
# Out:
# LinearRegression()

# %%
# Intercept and coefficients
print("Intercept:", linreg_5.intercept_)

print("Number of Original features:", X_train.shape[1])

print("Number of Total features:", X_train_poly_5.shape[1])

print("Number of Interaction features:", X_train_poly_5.shape[1] - X_train.shape[1] - X_train.shape[1])
print("\nCoefficients:")

# # Show all coefficients with their corresponding feature names for degree 2 polynomial features
feature_names_5 = poly_5.get_feature_names_out(X.columns)
# for name, coef in zip(feature_names_5, linreg_5.coef_):
#     print(f"{name:60s}: {coef:.4f}")

print("The Above code is commented out to avoid printing too many lines. You can uncomment it to see the coefficients.")
# Out:
# Intercept: -100.65431910503634
# Number of Original features: 13
# Number of Total features: 8567
# Number of Interaction features: 8541
#
# Coefficients:
# The Above code is commented out to avoid printing too many lines. You can uncomment it to see the coefficients.

# %%
# Feature importance (absolute value of coefficients)
feature_importance_5 = pd.Series(np.abs(linreg_5.coef_), index=feature_names_5)
top10_5 = feature_importance_5.sort_values(ascending=False).head(10)
print("\nTop 10 Feature Importances for degee 2:")
print(top10_5)
# Out:
# Top 10 Feature Importances for degee 2:
# Avg_Rooms^2 Pre_War_Built_Pct Black_Residents_Pct^2                                 2.264678e-07
# Crime_Rate^2 Employment_Center_Dist Property_TaxRate^2                              2.172611e-07
# Crime_Rate Black_Residents_Pct^2 Lower_Status_Pct^2                                 2.088057e-07
# Industrial_Pct Nitrogen_Oxides Black_Residents_Pct^3                                1.904283e-07
# Crime_Rate Industrial_Pct Pre_War_Built_Pct Property_TaxRate^2                      1.887762e-07
# Charles_River_Access Avg_Rooms Black_Residents_Pct^3                                1.878297e-07
# Industrial_Pct Avg_Rooms Pre_War_Built_Pct Property_TaxRate^2                       1.657437e-07
# Residential_Zoning Pre_War_Built_Pct Property_TaxRate^2 Pupil_Teacher_Ratio         1.633481e-07
# Crime_Rate Industrial_Pct Pre_War_Built_Pct Property_TaxRate Black_Residents_Pct    1.632720e-07
# ...

# %%
# Predictions
y_train_pred_5 = linreg_5.predict(X_train_poly_5)
y_test_pred_5 = linreg_5.predict(X_test_poly_5)

# Metrics
train_rmse_5 = root_mean_squared_error(y_train, y_train_pred_5)
test_rmse_5 = root_mean_squared_error(y_test, y_test_pred_5)
train_r2_5 = r2_score(y_train, y_train_pred_5)
test_r2_5 = r2_score(y_test, y_test_pred_5)

print(f"\nTrain RMSE for degree 5: {train_rmse_5:.4f}")
print(f"Test RMSE for degree 5:  {test_rmse_5:.4f}")
print(f"Train R2 for degree 5:   {train_r2_5:.4f}")
print(f"Test R2 for degree 5:    {test_r2_5:.4f}")
# Out:
# Train RMSE for degree 5: 0.0000
# Test RMSE for degree 5:  254.1837
# Train R2 for degree 5:   1.0000
# Test R2 for degree 5:    -866.0873

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred_5, alpha=0.7, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price (Degree 5)')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="poly_degree_6"></a>
# <div style="border-radius:10px; border-left:5px solid #EEE8AA; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-left: 30px; margin-bottom: 20px;">
#   <h3 style="color: #8B4513; margin-top: 0;">4.6 Polynomial Degree 6</h3>
#   <p style="color: #000000;">Regression model using polynomial features of degree 6.</p>
# </div>

# %%
# Degree 6 polynomial features 
poly_6 = PolynomialFeatures(degree=6, include_bias=False)
X_train_poly_6 = poly_6.fit_transform(X_train)
X_test_poly_6 = poly_6.transform(X_test)

# %%
# Fit linear regression
linreg_6 = LinearRegression()
linreg_6.fit(X_train_poly_6, y_train)
# Out:
# LinearRegression()

# %%
# Intercept and coefficients
print("Intercept:", linreg_6.intercept_)

print("Number of Original features:", X_train.shape[1])

print("Number of Total features:", X_train_poly_6.shape[1])

print("Number of Interaction features:", X_train_poly_6.shape[1] - X_train.shape[1] - X_train.shape[1])
print("\nCoefficients:")

# # Show all coefficients with their corresponding feature names for degree 2 polynomial features
feature_names_6 = poly_6.get_feature_names_out(X.columns)
# for name, coef in zip(feature_names_6, linreg_6.coef_):
#     print(f"{name:60s}: {coef:.4f}")

print("The Above code is commented out to avoid printing too many lines. You can uncomment it to see the coefficients.")
# Out:
# Intercept: -59.144150504051865
# Number of Original features: 13
# Number of Total features: 27131
# Number of Interaction features: 27105
#
# Coefficients:
# The Above code is commented out to avoid printing too many lines. You can uncomment it to see the coefficients.

# %%
# Feature importance (absolute value of coefficients)
feature_importance_6 = pd.Series(np.abs(linreg_6.coef_), index=feature_names_6)
top10_6 = feature_importance_6.sort_values(ascending=False).head(10)
print("\nTop 10 Feature Importances for degee 2:")
print(top10_6)
# Out:
# Top 10 Feature Importances for degee 2:
# Industrial_Pct Nitrogen_Oxides Black_Residents_Pct^4                         3.695326e-10
# Charles_River_Access Avg_Rooms Black_Residents_Pct^4                         3.555018e-10
# Avg_Rooms^2 Pre_War_Built_Pct Black_Residents_Pct^3                          3.483038e-10
# Residential_Zoning Employment_Center_Dist^2 Black_Residents_Pct^3            2.973769e-10
# Crime_Rate Black_Residents_Pct^3 Lower_Status_Pct^2                          2.823445e-10
# Nitrogen_Oxides Highway_Access Property_TaxRate^4                            2.588930e-10
# Crime_Rate^2 Employment_Center_Dist Property_TaxRate^3                       2.506193e-10
# Industrial_Pct Avg_Rooms Pre_War_Built_Pct Property_TaxRate^3                2.422182e-10
# Pre_War_Built_Pct Employment_Center_Dist^2 Black_Residents_Pct^3             2.413402e-10
# Industrial_Pct Pupil_Teacher_Ratio Black_Residents_Pct^3 Lower_Status_Pct    2.402708e-10
# dtype: float64

# %%
# Predictions
y_train_pred_6 = linreg_6.predict(X_train_poly_6)
y_test_pred_6 = linreg_6.predict(X_test_poly_6)

# Metrics
train_rmse_6 = root_mean_squared_error(y_train, y_train_pred_6)
test_rmse_6 = root_mean_squared_error(y_test, y_test_pred_6)
train_r2_6 = r2_score(y_train, y_train_pred_6)
test_r2_6 = r2_score(y_test, y_test_pred_6)

print(f"\nTrain RMSE for Degree 6: {train_rmse_6:.4f}")
print(f"Test RMSE for Degree 6:  {test_rmse_6:.4f}")
print(f"Train R2 for Degree 6:   {train_r2_6:.4f}")
print(f"Test R2 for Degree 6:    {test_r2_6:.4f}")
# Out:
# Train RMSE for Degree 6: 0.0000
# Test RMSE for Degree 6:  215.7669
# Train R2 for Degree 6:   1.0000
# Test R2 for Degree 6:    -623.7943

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred_6, alpha=0.7, color='teal')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price (Degree 6)')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="poly_selected_features"></a>
# <div style="border-radius:10px; border-left:5px solid #DAA520; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-bottom: 20px;">
#   <h2 style="color: #8B4513; margin-top: 0;">6. Polynomial Terms for Selected Features</h2>
#   <p style="color: #000000;">We generate polynomial terms only for the features identified as significant in the previous step.</p>
# </div>

# %%
# Add missing imports if not already imported in previous cells
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# All features
all_features = X_train.columns.tolist()
selected_features = ['Nitrogen_Oxides', 'Avg_Rooms', 'Charles_River_Access', 'Employment_Center_Dist', 'Pupil_Teacher_Ratio']

# Features not in selected_features
other_features = [f for f in all_features if f not in selected_features]

X_sel_train = X_train[selected_features]
X_sel_test = X_test[selected_features]
X_other_train = X_train[other_features]
X_other_test = X_test[other_features]

results = {}

for degree in [2, 3, 4, 5, 6]:
    poly = PolynomialFeatures(degree=degree, include_bias=False)
    X_sel_train_poly = poly.fit_transform(X_sel_train)
    X_sel_test_poly = poly.transform(X_sel_test)

    # Concatenate polynomial features with other features
    X_train_combined = np.hstack([X_sel_train_poly, X_other_train.values])
    X_test_combined = np.hstack([X_sel_test_poly, X_other_test.values])

    model = LinearRegression()
    model.fit(X_train_combined, y_train)

    y_train_pred = model.predict(X_train_combined)
    y_test_pred = model.predict(X_test_combined)

    train_rmse = root_mean_squared_error(y_train, y_train_pred)
    test_rmse = root_mean_squared_error(y_test, y_test_pred)
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)

    results[degree] = {
        'train_rmse': train_rmse,
        'test_rmse': test_rmse,
        'train_r2': train_r2,
        'test_r2': test_r2,
        'y_test_pred': y_test_pred
    }

    print(f"\nPolynomial Degree {degree}:")
    print("Number of Total features:", X_train_combined.shape[1])
    print("Number of polynomial features:", X_sel_train_poly.shape[1])
    print("Number of other features:", X_other_train.shape[1])
    print("Model Intercept:", model.intercept_)
    print("\nCoefficients:")
    print("Top 10 Feature Importances:")
    # Fix: concatenate arrays for index
    feature_names_combined = np.concatenate([poly.get_feature_names_out(selected_features), np.array(other_features)])
    feature_importance_combined = pd.Series(np.abs(model.coef_), index=feature_names_combined)
    print(feature_importance_combined.sort_values(ascending=False).head(10))
    print("\n")
    print(f"Train RMSE: {train_rmse:.4f}")
    print(f"Test RMSE:  {test_rmse:.4f}")
    print(f"Train R2:   {train_r2:.4f}")
    print(f"Test R2:    {test_r2:.4f}")

    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_test_pred, alpha=0.7, color='teal')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    plt.title(f'Actual vs Predicted Price (Degree {degree}, Poly on Selected Features)')
    plt.grid(True)
    plt.show()
# Out:
# Polynomial Degree 2:
# Number of Total features: 28
# Number of polynomial features: 20
# Number of other features: 8
# Model Intercept: -122.85795949422273
#
# Coefficients:
# Top 10 Feature Importances:
# Nitrogen_Oxides                           60.978461
# Nitrogen_Oxides^2                         43.576088
# Nitrogen_Oxides Charles_River_Access      41.583024
# Avg_Rooms                                 22.235196
# Nitrogen_Oxides Avg_Rooms                 19.538296
# Charles_River_Access^2                    10.822860
# Charles_River_Access                      10.822860
# Nitrogen_Oxides Employment_Center_Dist    10.156908
# Employment_Center_Dist                     9.190835
# Pupil_Teacher_Ratio                        8.640156
# dtype: float64
#
#
# Train RMSE: 3.5956
# Test RMSE:  3.6207
# Train R2:   0.8529
# Test R2:    0.8241
# Polynomial Degree 3:
# Number of Total features: 63
# Number of polynomial features: 55
# Number of other features: 8
# ...

# %%
# Select only the significant features

X_sel_train = X_train[selected_features]
X_sel_test = X_test[selected_features]

results = {}

for degree in [2, 3, 4, 5, 6]:
    poly = PolynomialFeatures(degree=degree, include_bias=False)
    X_sel_train_poly = poly.fit_transform(X_sel_train)
    X_sel_test_poly = poly.transform(X_sel_test)

    model = LinearRegression()
    model.fit(X_sel_train_poly, y_train)

    y_train_pred = model.predict(X_sel_train_poly)
    y_test_pred = model.predict(X_sel_test_poly)

    train_rmse = root_mean_squared_error(y_train, y_train_pred)
    test_rmse = root_mean_squared_error(y_test, y_test_pred)
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)

    results[degree] = {
        'train_rmse': train_rmse,
        'test_rmse': test_rmse,
        'train_r2': train_r2,
        'test_r2': test_r2,
        'y_test_pred': y_test_pred
    }

    print("Number of Original features:", X_sel_train.shape[1])
    print("Number of Total features:", X_sel_train_poly.shape[1])

    print(f"\nPolynomial Degree {degree}:")
    print(f"Train RMSE: {train_rmse:.4f}")
    print(f"Test RMSE:  {test_rmse:.4f}")
    print(f"Train R2:   {train_r2:.4f}")
    print(f"Test R2:    {test_r2:.4f}")

    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_test_pred, alpha=0.7, color='teal')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    plt.title(f'Actual vs Predicted Price (Degree {degree}, Selected Features)')
    plt.grid(True)
    plt.show()
# Out:
# Number of Original features: 28
#
# Polynomial Degree 2:
# Train RMSE: 3.5956
# Test RMSE:  3.6207
# Train R2:   0.8529
# Test R2:    0.8241
# Number of Original features: 63
#
# Polynomial Degree 3:
# Train RMSE: 2.9500
# Test RMSE:  4.3151
# Train R2:   0.9010
# Test R2:    0.7501
# Number of Original features: 133
#
# Polynomial Degree 4:
# Train RMSE: 2.5875
# Test RMSE:  5.3004
# Train R2:   0.9238
# Test R2:    0.6230
# Number of Original features: 259
#
# Polynomial Degree 5:
# Train RMSE: 2.1131
# Test RMSE:  12.8540
# Train R2:   0.9492
# Test R2:    -1.2174
# Number of Original features: 469
#
# Polynomial Degree 6:
# Train RMSE: 1.6298
# Test RMSE:  21.5381
# Train R2:   0.9698
# Test R2:    -5.2256

# %% [markdown]
# <a id="bias_variance_analysis"></a>
# <div style="border-radius:10px; border-left:5px solid #DAA520; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-bottom: 20px;">
#   <h2 style="color: #8B4513; margin-top: 0;">7. Bias-Variance Analysis</h2>
#   <p style="color: #000000;">In this section, I Tried to analyze the bias-variance tradeoff across different polynomial degrees.</p>
# </div>

# %% [markdown]
# <a id="rmse"></a>
# <div style="border-radius:10px; border-left:5px solid #EEE8AA; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-left: 30px; margin-bottom: 20px;">
#   <h3 style="color: #8B4513; margin-top: 0;">7.1 RMSE</h3>
#   <p style="color: #000000;">Root Mean Square Error analysis for different polynomial degrees.</p>
# </div>

# %%
# Feature Selected values
model_complexity = [1, 2, 3, 4, 5, 6]
num_features = [13, 28, 63, 133, 259, 469]
train_rmse = [4.7482, 3.5956, 2.9500, 2.5875, 2.1131, 1.6298]
test_rmse = [4.6387, 3.6207, 4.3151, 5.3004, 12.8540, 21.5381]
train_r2 = [0.7435, 0.8529, 0.9010, 0.9238, 0.9492, 0.9698]
test_r2 = [0.7112, 0.8241, 0.7501, 0.6230, -1.2174, -5.2256]

# %%
model_complexity = [1, 2, 3, 4, 5 ,6]
train_errors = [4.7482, 2.1588, 0.0000, 0.0000, 0.0000, 0.0000]
test_errors = [4.6387, 5.0257, 167.7589, 283.8173, 254.1837, 215.7669]

optimal_idx = np.argmin(test_errors)
optimal_complexity = model_complexity[:len(test_errors)][optimal_idx]

plt.figure(figsize=(10, 6))
plt.plot(model_complexity, train_errors, marker='o', linestyle='-', color='blue', label='Training Error (RMSE)')
plt.plot(model_complexity, test_errors, marker='o', linestyle='-', color='orange', label='Test Error (RMSE)')

if optimal_idx > 0:
	plt.axvspan(model_complexity[0] - 0.5, model_complexity[optimal_idx-1] + 0.5, alpha=0.15, color='blue', lw=0, label='Underfitting / High Bias')
elif optimal_idx == 0 and len(model_complexity) > 1 :
	plt.axvspan(model_complexity[0] - 0.5, model_complexity[0] + 0.5, alpha=0.15, color='green', lw=0, label='Optimal (Potentially simple)')

plt.axvspan(model_complexity[optimal_idx] - 0.5, model_complexity[optimal_idx] + 0.5, alpha=0.2, color='green', lw=0, label='Good Balance / Optimal')

if optimal_idx < len(model_complexity) - 1:
	plt.axvspan(model_complexity[optimal_idx+1] - 0.5, model_complexity[-1] + 0.5, alpha=0.15, color='red', lw=0, label='Overfitting / High Variance')

plt.xlabel('Model Complexity (Polynomial Degree)')
plt.ylabel('RMSE')
plt.title('Bias-Variance Tradeoff: Model Complexity vs. RMSE')
plt.xticks(model_complexity)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
num_features = [13, 104, 559, 2379, 8567, 27131]
train_errors = [4.7482, 2.1588, 0.0000, 0.0000, 0.0000, 0.0000]
test_errors = [4.6387, 5.0257, 167.7589, 283.8173, 254.1837, 215.7669]

optimal_idx_features_rmse = np.argmin(test_errors)
optimal_features_rmse = num_features[:len(test_errors)][optimal_idx_features_rmse]

plt.figure(figsize=(10, 6))
plt.plot(num_features, train_errors, marker='o', linestyle='-', color='blue', label='Training Error (RMSE)')
plt.plot(num_features, test_errors, marker='o', linestyle='-', color='orange', label='Test Error (RMSE)')
plt.xscale('log')

if optimal_idx_features_rmse > 0:
	plt.axvspan(num_features[:len(test_errors)][0] / 1.5, num_features[:len(test_errors)][optimal_idx_features_rmse-1] * 1.5, alpha=0.15, color='blue', lw=0, label='Underfitting / High Bias')
elif optimal_idx_features_rmse == 0 and len(num_features) > 1:
	plt.axvspan(num_features[:len(test_errors)][0] / 1.5, num_features[:len(test_errors)][0] * 1.5, alpha=0.15, color='green', lw=0, label='Optimal (Potentially simple)')

plt.axvspan(num_features[:len(test_errors)][optimal_idx_features_rmse] / 1.5, num_features[:len(test_errors)][optimal_idx_features_rmse] * 1.5, alpha=0.2, color='green', lw=0, label='Good Balance / Optimal')

if optimal_idx_features_rmse < len(num_features[:len(test_errors)]) - 1:
	plt.axvspan(num_features[:len(test_errors)][optimal_idx_features_rmse+1] / 1.5, num_features[-1] * 1.5, alpha=0.15, color='red', lw=0, label='Overfitting / High Variance')

plt.xlabel('Number of Features (Log Scale)')
plt.ylabel('RMSE')
plt.title('Bias-Variance Tradeoff: Number of Features vs. RMSE')
plt.grid(True, which="both", linestyle='--', alpha=0.7)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plot 1: Model Complexity vs. RMSE
optimal_idx_rmse = np.argmin(test_rmse)
optimal_complexity_rmse = model_complexity[optimal_idx_rmse]

plt.figure(figsize=(10, 6))
plt.plot(model_complexity, train_rmse, marker='o', linestyle='-', color='blue', label='Training Error (RMSE)')
plt.plot(model_complexity, test_rmse, marker='o', linestyle='-', color='orange', label='Test Error (RMSE)')

# Underfitting / High Bias region
if optimal_idx_rmse > 0:
    plt.axvspan(model_complexity[0] - 0.5, model_complexity[optimal_idx_rmse-1] + 0.5, alpha=0.15, color='blue', lw=0, label='Underfitting / High Bias')
elif optimal_idx_rmse == 0 and len(model_complexity) > 1: # Optimal is the first point, potentially simplest model
    plt.axvspan(model_complexity[0] - 0.5, model_complexity[0] + 0.5, alpha=0.15, color='green', lw=0, label='Optimal (Potentially simple)')


# Good Balance / Optimal region
plt.axvspan(model_complexity[optimal_idx_rmse] - 0.5, model_complexity[optimal_idx_rmse] + 0.5, alpha=0.2, color='green', lw=0, label='Good Balance / Optimal')

# Overfitting / High Variance region
if optimal_idx_rmse < len(model_complexity) - 1:
    plt.axvspan(model_complexity[optimal_idx_rmse+1] - 0.5, model_complexity[-1] + 0.5, alpha=0.15, color='red', lw=0, label='Overfitting / High Variance')

plt.xlabel('Model Complexity (Polynomial Degree)')
plt.ylabel('RMSE')
plt.title('Bias-Variance Tradeoff: Model Complexity vs. RMSE (Feature Selected)')
plt.xticks(model_complexity)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Plot 3: Number of Features vs. RMSE
optimal_num_features_rmse = num_features[optimal_idx_rmse]


plt.figure(figsize=(10, 6))
plt.plot(num_features, train_rmse, marker='o', linestyle='-', color='blue', label='Training Error (RMSE)')
plt.plot(num_features, test_rmse, marker='o', linestyle='-', color='orange', label='Test Error (RMSE)')
plt.xscale('log')

# Underfitting / High Bias region
if optimal_idx_rmse > 0:
    plt.axvspan(num_features[0] / 1.5, num_features[optimal_idx_rmse-1] * 1.5, alpha=0.15, color='blue', lw=0, label='Underfitting / High Bias')
elif optimal_idx_rmse == 0 and len(num_features) > 1:
    plt.axvspan(num_features[0] / 1.5, num_features[0] * 1.5, alpha=0.15, color='green', lw=0, label='Optimal (Potentially simple)')

# Good Balance / Optimal region
plt.axvspan(num_features[optimal_idx_rmse] / 1.5, num_features[optimal_idx_rmse] * 1.5, alpha=0.2, color='green', lw=0, label='Good Balance / Optimal')

# Overfitting / High Variance region
if optimal_idx_rmse < len(num_features) - 1:
    plt.axvspan(num_features[optimal_idx_rmse+1] / 1.5, num_features[-1] * 1.5, alpha=0.15, color='red', lw=0, label='Overfitting / High Variance')

plt.xlabel('Number of Features (Log Scale)')
plt.ylabel('RMSE')
plt.title('Bias-Variance Tradeoff: Number of Features vs. RMSE (Feature Selected)')
plt.grid(True, which="both", linestyle='--', alpha=0.7)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Old data (from your previous example code for comparison)
old_model_complexity = [1, 2, 3, 4, 5 ,6]
old_test_errors_rmse = [4.6387, 5.0257, 167.7589, 283.8173, 254.1837, 215.7669]
old_test_errors_r2 = [0.7112, 0.6610, -376.6928, -1080.0481, -866.0873, -623.7943] # from your previous R2 plot

plt.figure(figsize=(12, 7))
plt.plot(model_complexity, test_rmse, marker='o', linestyle='-', color='orange', label='Test RMSE (New - Feature Selected)')
plt.plot(old_model_complexity, old_test_errors_rmse, marker='x', linestyle='--', color='red', label='Test RMSE (Old - All Features Poly)')

optimal_idx_new = np.argmin(test_rmse)
plt.scatter(model_complexity[optimal_idx_new], test_rmse[optimal_idx_new], s=100, c='orange', marker='*', label=f'Optimal New (Degree {model_complexity[optimal_idx_new]})')

optimal_idx_old = np.argmin(old_test_errors_rmse)
plt.scatter(old_model_complexity[optimal_idx_old], old_test_errors_rmse[optimal_idx_old], s=100, c='red', marker='P', label=f'Optimal Old (Degree {old_model_complexity[optimal_idx_old]})')


plt.xlabel('Model Complexity (Polynomial Degree)')
plt.ylabel('Test RMSE')
plt.title('Comparison: Test RMSE vs. Model Complexity (Old vs. New Feature Selection)')
plt.xticks(model_complexity)
plt.legend(loc='upper left')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="r_squared"></a>
# <div style="border-radius:10px; border-left:5px solid #EEE8AA; padding: 15px; background-color: #FFFAF0; font-size:100%; margin-left: 30px; margin-bottom: 20px;">
#   <h3 style="color: #8B4513; margin-top: 0;">7.2 R²</h3>
#   <p style="color: #000000;">Coefficient of determination (R²) analysis for different polynomial degrees.</p>
# </div>

# %%
model_complexity = [1, 2, 3, 4, 5 ,6]
train_r2 = [0.7435, 0.9470, 1.0000, 1.0000, 1.0000, 1.0000]
test_r2 = [0.7112, 0.6610, -376.6928, -1080.0481, -866.0873, -623.7943]

optimal_idx_r2 = np.argmax(test_r2)
optimal_complexity_r2 = model_complexity[:len(test_r2)][optimal_idx_r2]

plt.figure(figsize=(10, 6))
plt.plot(model_complexity, train_r2, marker='o', linestyle='-', color='blue', label='Training R2')
plt.plot(model_complexity, test_r2, marker='o', linestyle='-', color='orange', label='Test R2')

if optimal_idx_r2 > 0:
	plt.axvspan(model_complexity[:len(test_r2)][0] - 0.5, model_complexity[:len(test_r2)][optimal_idx_r2-1] + 0.5, alpha=0.15, color='blue', lw=0, label='Underfitting / High Bias')
elif optimal_idx_r2 == 0 and len(model_complexity) > 1:
	plt.axvspan(model_complexity[:len(test_r2)][0] - 0.5, model_complexity[:len(test_r2)][0] + 0.5, alpha=0.15, color='green', lw=0, label='Optimal (Potentially simple)')

plt.axvspan(model_complexity[:len(test_r2)][optimal_idx_r2] - 0.5, model_complexity[:len(test_r2)][optimal_idx_r2] + 0.5, alpha=0.2, color='green', lw=0, label='Good Balance / Optimal')

if optimal_idx_r2 < len(model_complexity[:len(test_r2)]) - 1:
	plt.axvspan(model_complexity[:len(test_r2)][optimal_idx_r2+1] - 0.5, model_complexity[-1] + 0.5, alpha=0.15, color='red', lw=0, label='Overfitting / High Variance')

plt.xlabel('Model Complexity (Polynomial Degree)')
plt.ylabel('R2 Score')
plt.title('Bias-Variance Tradeoff: Model Complexity vs. R2')
plt.xticks(model_complexity)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='lower left')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
num_features = [13, 104, 559, 2379, 8567, 27131]
train_r2 = [0.7435, 0.9470, 1.0000, 1.0000, 1.0000, 1.0000]
test_r2 = [0.7112, 0.6610, -376.6928, -1080.0481, -866.0873, -623.7943]

optimal_idx_features_r2 = np.argmax(test_r2)
optimal_features_r2 = num_features[:len(test_r2)][optimal_idx_features_r2]

plt.figure(figsize=(10, 6))
plt.plot(num_features, train_r2, marker='o', linestyle='-', color='blue', label='Training R2')
plt.plot(num_features, test_r2, marker='o', linestyle='-', color='orange', label='Test R2')
plt.xscale('log')

if optimal_idx_features_r2 > 0:
	plt.axvspan(num_features[:len(test_r2)][0] / 1.5, num_features[:len(test_r2)][optimal_idx_features_r2-1] * 1.5, alpha=0.15, color='blue', lw=0, label='Underfitting / High Bias')
elif optimal_idx_features_r2 == 0 and len(num_features) > 1:
	plt.axvspan(num_features[:len(test_r2)][0] / 1.5, num_features[:len(test_r2)][0] * 1.5, alpha=0.15, color='green', lw=0, label='Optimal (Potentially simple)')

plt.axvspan(num_features[:len(test_r2)][optimal_idx_features_r2] / 1.5, num_features[:len(test_r2)][optimal_idx_features_r2] * 1.5, alpha=0.2, color='green', lw=0, label='Good Balance / Optimal')

if optimal_idx_features_r2 < len(num_features[:len(test_r2)]) - 1:
	plt.axvspan(num_features[:len(test_r2)][optimal_idx_features_r2+1] / 1.5, num_features[-1] * 1.5, alpha=0.15, color='red', lw=0, label='Overfitting / High Variance')

plt.xlabel('Number of Features (Log Scale)')
plt.ylabel('R2 Score')
plt.title('Bias-Variance Tradeoff: Number of Features vs. R2')
plt.grid(True, which="both", linestyle='--', alpha=0.7)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='lower left')
plt.tight_layout()
plt.show()

# %%
# Plot 2: Model Complexity vs. R2
optimal_idx_r2_mc = np.argmax(test_r2) # Maximize R2
optimal_complexity_r2_mc = model_complexity[optimal_idx_r2_mc]

plt.figure(figsize=(10, 6))
plt.plot(model_complexity, train_r2, marker='o', linestyle='-', color='blue', label='Training R2')
plt.plot(model_complexity, test_r2, marker='o', linestyle='-', color='orange', label='Test R2')

# Underfitting / High Bias region
if optimal_idx_r2_mc > 0:
    plt.axvspan(model_complexity[0] - 0.5, model_complexity[optimal_idx_r2_mc-1] + 0.5, alpha=0.15, color='blue', lw=0, label='Underfitting / High Bias')
elif optimal_idx_r2_mc == 0 and len(model_complexity) > 1:
     plt.axvspan(model_complexity[0] - 0.5, model_complexity[0] + 0.5, alpha=0.15, color='green', lw=0, label='Optimal (Potentially simple)')

# Good Balance / Optimal region
plt.axvspan(model_complexity[optimal_idx_r2_mc] - 0.5, model_complexity[optimal_idx_r2_mc] + 0.5, alpha=0.2, color='green', lw=0, label='Good Balance / Optimal')

# Overfitting / High Variance region
if optimal_idx_r2_mc < len(model_complexity) - 1:
    plt.axvspan(model_complexity[optimal_idx_r2_mc+1] - 0.5, model_complexity[-1] + 0.5, alpha=0.15, color='red', lw=0, label='Overfitting / High Variance')


plt.xlabel('Model Complexity (Polynomial Degree)')
plt.ylabel('R2 Score')
plt.title('Bias-Variance Tradeoff: Model Complexity vs. R2 (Feature Selected)')
plt.xticks(model_complexity)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='lower left')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Plot 4: Number of Features vs. R2
optimal_num_features_r2 = num_features[optimal_idx_r2_mc]

plt.figure(figsize=(10, 6))
plt.plot(num_features, train_r2, marker='o', linestyle='-', color='blue', label='Training R2')
plt.plot(num_features, test_r2, marker='o', linestyle='-', color='orange', label='Test R2')
plt.xscale('log')

# Underfitting / High Bias region
if optimal_idx_r2_mc > 0:
    plt.axvspan(num_features[0] / 1.5, num_features[optimal_idx_r2_mc-1] * 1.5, alpha=0.15, color='blue', lw=0, label='Underfitting / High Bias')
elif optimal_idx_r2_mc == 0 and len(num_features) > 1:
    plt.axvspan(num_features[0] / 1.5, num_features[0] * 1.5, alpha=0.15, color='green', lw=0, label='Optimal (Potentially simple)')


# Good Balance / Optimal region
plt.axvspan(num_features[optimal_idx_r2_mc] / 1.5, num_features[optimal_idx_r2_mc] * 1.5, alpha=0.2, color='green', lw=0, label='Good Balance / Optimal')

# Overfitting / High Variance region
if optimal_idx_r2_mc < len(num_features) - 1:
    plt.axvspan(num_features[optimal_idx_r2_mc+1] / 1.5, num_features[-1] * 1.5, alpha=0.15, color='red', lw=0, label='Overfitting / High Variance')


plt.xlabel('Number of Features (Log Scale)')
plt.ylabel('R2 Score')
plt.title('Bias-Variance Tradeoff: Number of Features vs. R2 (Feature Selected)')
plt.grid(True, which="both", linestyle='--', alpha=0.7)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='lower left') # R2 can be negative, so lower left is often better
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(model_complexity, test_r2, marker='o', linestyle='-', color='orange', label='Test R2 (New - Feature Selected)')
plt.plot(old_model_complexity, old_test_errors_r2, marker='x', linestyle='--', color='red', label='Test R2 (Old - All Features Poly)')


optimal_idx_new_r2 = np.argmax(test_r2)
plt.scatter(model_complexity[optimal_idx_new_r2], test_r2[optimal_idx_new_r2], s=100, c='orange', marker='*', label=f'Optimal New (Degree {model_complexity[optimal_idx_new_r2]})')

optimal_idx_old_r2 = np.argmax(old_test_errors_r2)
plt.scatter(old_model_complexity[optimal_idx_old_r2], old_test_errors_r2[optimal_idx_old_r2], s=100, c='red', marker='P', label=f'Optimal Old (Degree {old_model_complexity[optimal_idx_old_r2]})')

plt.xlabel('Model Complexity (Polynomial Degree)')
plt.ylabel('Test R2 Score')
plt.title('Comparison: Test R2 vs. Model Complexity (Old vs. New Feature Selection)')
plt.xticks(model_complexity)
plt.legend(loc='upper right') # R2 has a wide range, adjust legend if needed
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
